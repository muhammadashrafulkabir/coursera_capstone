# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
import folium # map rendering library



res = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
#print(res)
soup = BeautifulSoup(res,"lxml")



df = pd.DataFrame(columns=['Postal Code','Borough','Neighbourhood']) # I know the size



for table in soup.findAll("table", {"class": "wikitable sortable"}):
    row_marker = 0
    #iterate and apply logic to clean the data
    for row in table.find_all('tr'):
        if(len(row)==6):
            columns = row.find_all('td')
            if len(columns)>0:
                nan=0
                if columns[1].text!='Not assigned':
                    if columns[2].text=='Not assigned\n':
                        #df.loc[df['Postal Code'] == columns[0].text] = columns[1].text
                        #print(df.loc[df['Postal Code'] == columns[0].text].values)
                        #columns[2].text=columns[1].text
                        nan=1
                        


                        #print(columns[1].text)
                    
                    for ind,t in df.iterrows():
                        if t['Borough']==columns[1].text:
                            t['Neighbourhood']=t['Neighbourhood']+", "+columns[2].text
                           
                    if columns[0].text not in df.values:
                        
                        if nan != 0:
                            #append to the empty dataframe
                            df=df.append({'Postal Code':columns[0].text,'Borough':columns[1].text,'Neighbourhood':columns[1].text},ignore_index=True)
                        else:
                            df=df.append({'Postal Code':columns[0].text,'Borough':columns[1].text,'Neighbourhood':columns[2].text},ignore_index=True)
                            nan=0

#Replace all \n
df=df.replace(to_replace='\n', value='', regex=True)

#print(df)
#df
#df.shape

df_geo=pd.read_csv("Geospatial_Coordinates.csv")
#print (df_geo)
df_new=pd.merge (df,df_geo,on="Postal Code")
#print (df_new)

df_grouped = df_new.groupby('Neighbourhood').mean().reset_index()
print(df_grouped)

# set number of clusters
kclusters = 5

df_clustering = df_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

df_merged = df_clustering

# add clustering labels
df_merged['Cluster Labels'] = kmeans.labels_


#print(df_merged.head()) # check the last columns!

latitude=43.6542599
longitude=-79.3606359

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

#print (folium.__version__)


# add markers to the map
markers_colors = []
for lat, lon, cluster in zip(df_merged['Latitude'], df_merged['Longitude'], df_merged['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

#map_clusters.save('map1.html')
# Out:
#                                          Neighbourhood   Latitude  Longitude
# 0    Adelaide, King, Richmond, Harbourfront East, T...  43.650571 -79.384568
# 1    Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 2    Agincourt, Clarks Corners, Sullivan, Tam O'Sha...  43.794200 -79.262029
# 3    Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 4    Alderwood, Long Branch, Northwest, The Kingswa...  43.602414 -79.543484
# 5    Bathurst Manor, Downsview North, Wilson Height...  43.754328 -79.442259
# 6    Bayview Village, CFB Toronto, Downsview East, ...  43.786947 -79.385975
# 7    Bedford Park, Lawrence Manor East, Emery, Humb...  43.733283 -79.419750
# 8    Berczy Park, Central Bay Street, Christie, Ade...  43.644771 -79.373306
# 9    Birch Cliff, Cliffside West, Dorset Park, Scar...  43.692657 -79.264848
# 10   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 11   Brockton, Exhibition Place, Parkdale Village, ...  43.636847 -79.428191
# 12    Business reply mail Processing Centre969 Eastern  43.662744 -79.321558
# 13   CFB Toronto, Downsview East, Silver Hills, Yor...  43.737473 -79.464763
# 14   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 15   Cabbagetown, St. James Town, First Canadian Pl...  43.667967 -79.367675
# 16   Caledonia-Fairbanks, Del Ray, Keelsdale, Mount...  43.689026 -79.453512
# 17               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 18   Cedarbrae, Scarborough Village, East Birchmoun...  43.773136 -79.239476
# 19   Central Bay Street, Christie, Adelaide, King, ...  43.657952 -79.387383
# 20   Chinatown, Grange Park, Kensington Market, CN ...  43.653206 -79.400049
# 21   Christie, Adelaide, King, Richmond, Harbourfro...  43.669542 -79.422564
# 22                                Church and Wellesley  43.665860 -79.383160
# 23   Clairlea, Golden Mile, Oakridge, Cliffcrest, C...  43.711112 -79.284577
# 24   Clarks Corners, Sullivan, Tam O'Shanter, Aginc...  43.781638 -79.304302
# 25   Cliffcrest, Cliffside, Scarborough Village Wes...  43.716316 -79.239476
# 26   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 27   Commerce Court, Victoria Hotel, Harbord, Unive...  43.648198 -79.379817
# 28   Davisville North, Forest Hill North, Forest Hi...  43.712751 -79.390197
# 29   Davisville, Moore Park, Summerhill East, Deer ...  43.704324 -79.388790
# ..                                                 ...        ...        ...
# 73          Parkdale, Roncesvalles, Runnymede, Swansea  43.648960 -79.456325
# 74   Parkwoods, Victoria Village, Lawrence Heights,...  43.753259 -79.329656
# 75                                        Queen's Park  43.662301 -79.389494
# 76   Rosedale, Stn A PO Boxes 25 The Esplanade, Cab...  43.679563 -79.377529
# 77   Roselawn, Davisville North, Forest Hill North,...  43.711695 -79.416936
# 78   Rouge, Malvern, Highland Creek, Rouge Hill, Po...  43.806686 -79.194353
# 79                                  Runnymede, Swansea  43.651571 -79.484450
# 80   Ryerson, Garden District, St. James Town, Berc...  43.657162 -79.378937
# 81   Scarborough Village, East Birchmount Park, Ion...  43.744734 -79.239476
# 82   Silver Hills, York Mills, Downsview West, Mapl...  43.757490 -79.374714
# 83   St. James Town, Berczy Park, Central Bay Stree...  43.651494 -79.375418
# 84   Stn A PO Boxes 25 The Esplanade, Cabbagetown, ...  43.646435 -79.374846
# 85   Studio District, Business reply mail Processin...  43.659526 -79.340923
# 86   The Annex, North Midtown, Yorkville, Davisvill...  43.672710 -79.405678
# 87   The Beaches West, India Bazaar, Studio Distric...  43.668999 -79.315572
# 88   The Beaches, The Danforth West, Riverdale, The...  43.676357 -79.293031
# 89   The Danforth West, Riverdale, The Beaches West...  43.679557 -79.352188
# 90               The Junction North, Runnymede, Weston  43.673185 -79.487262
# 91   The Kingsway, Montgomery Road, Old Mill North,...  43.653654 -79.506944
# 92                      Thorncliffe Park, East Toronto  43.705369 -79.349372
# 93                                         Upper Rouge  43.836125 -79.205636
# 94   Victoria Village, Lawrence Heights, Lawrence M...  43.725882 -79.315572
# 95   Westmount, Kingsview Village, Martin Grove Gar...  43.696319 -79.532242
# 96                                              Weston  43.706876 -79.518188
# 97   Willowdale South, Downsview Northwest, York Mi...  43.770120 -79.408493
# 98                                     Willowdale West  43.782736 -79.442259
# 99   Woburn, Cedarbrae, Scarborough Village, East B...  43.770992 -79.216917
# 100  Woodbine Gardens, Parkview Hill, Woodbine Heig...  43.706397 -79.309937
# 101  Woodbine Heights, Leaside, Thorncliffe Park, E...  43.695344 -79.318389
# 102                   York Mills West, Willowdale West  43.752758 -79.400049
#
# [103 rows x 3 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
