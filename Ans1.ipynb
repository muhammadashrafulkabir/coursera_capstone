# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin



res = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
#print(res)
soup = BeautifulSoup(res,"lxml")



df = pd.DataFrame(columns=['Postal Code','Borough','Neighbourhood']) # I know the size



for table in soup.findAll("table", {"class": "wikitable sortable"}):
    row_marker = 0
    #iterate and apply logic to clean the data
    for row in table.find_all('tr'):
        if(len(row)==6):
            columns = row.find_all('td')
            if len(columns)>0:
                nan=0
                if columns[1].text!='Not assigned':
                    if columns[2].text=='Not assigned\n':
                        #df.loc[df['Postal Code'] == columns[0].text] = columns[1].text
                        #print(df.loc[df['Postal Code'] == columns[0].text].values)
                        #columns[2].text=columns[1].text
                        nan=1
                        


                        #print(columns[1].text)
                    
                    for ind,t in df.iterrows():
                        if t['Borough']==columns[1].text:
                            t['Neighbourhood']=t['Neighbourhood']+", "+columns[2].text
                           
                    if columns[0].text not in df.values:
                        
                        if nan != 0:
                            #append to the empty dataframe
                            df=df.append({'Postal Code':columns[0].text,'Borough':columns[1].text,'Neighbourhood':columns[1].text},ignore_index=True)
                        else:
                            df=df.append({'Postal Code':columns[0].text,'Borough':columns[1].text,'Neighbourhood':columns[2].text},ignore_index=True)
                            nan=0

#Replace all \n
df=df.replace(to_replace='\n', value='', regex=True)

print(df)
#df
print(df.shape)
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A      Queen's Park
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# 26          M1H       Scarborough
# 27          M2H        North York
# 28          M3H        North York
# 29          M4H         East York
# ..          ...               ...
# 73          M4R   Central Toronto
# 74          M5R   Central Toronto
# 75          M6R      West Toronto
# 76          M7R       Mississauga
# 77          M9R         Etobicoke
# 78          M1S       Scarborough
# 79          M4S   Central Toronto
# 80          M5S  Downtown Toronto
# 81          M6S      West Toronto
# 82          M1T       Scarborough
# 83          M4T   Central Toronto
# 84          M5T  Downtown Toronto
# 85          M1V       Scarborough
# 86          M4V   Central Toronto
# 87          M5V  Downtown Toronto
# 88          M8V         Etobicoke
# 89          M9V         Etobicoke
# 90          M1W       Scarborough
# 91          M4W  Downtown Toronto
# 92          M5W  Downtown Toronto
# 93          M8W         Etobicoke
# 94          M9W         Etobicoke
# 95          M1X       Scarborough
# 96          M4X  Downtown Toronto
# 97          M5X  Downtown Toronto
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0    Parkwoods, Victoria Village, Lawrence Heights,...
# 1    Victoria Village, Lawrence Heights, Lawrence M...
# 2    Harbourfront, Regent Park, Ryerson, Garden Dis...
# 3    Lawrence Heights, Lawrence Manor, Don Mills No...
# 4                                         Queen's Park
# 5    Islington Avenue, Cloverdale, Islington, Marti...
# 6    Rouge, Malvern, Highland Creek, Rouge Hill, Po...
# 7    Don Mills North, Glencairn, Flemingdon Park, D...
# 8    Woodbine Gardens, Parkview Hill, Woodbine Heig...
# 9    Ryerson, Garden District, St. James Town, Berc...
# 10   Glencairn, Flemingdon Park, Don Mills South, H...
# 11   Cloverdale, Islington, Martin Grove, Princess ...
# 12   Highland Creek, Rouge Hill, Port Union, Guildw...
# 13   Flemingdon Park, Don Mills South, Hillcrest Vi...
# 14   Woodbine Heights, Leaside, Thorncliffe Park, E...
# 15   St. James Town, Berczy Park, Central Bay Stree...
# 16   Humewood-Cedarvale, Caledonia-Fairbanks, Del R...
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18   Guildwood, Morningside, West Hill, Woburn, Ced...
# 19   The Beaches, The Danforth West, Riverdale, The...
# 20   Berczy Park, Central Bay Street, Christie, Ade...
# 21   Caledonia-Fairbanks, Del Ray, Keelsdale, Mount...
# 22   Woburn, Cedarbrae, Scarborough Village, East B...
# 23             Leaside, Thorncliffe Park, East Toronto
# 24   Central Bay Street, Christie, Adelaide, King, ...
# 25   Christie, Adelaide, King, Richmond, Harbourfro...
# 26   Cedarbrae, Scarborough Village, East Birchmoun...
# 27   Hillcrest Village, Bathurst Manor, Downsview N...
# 28   Bathurst Manor, Downsview North, Wilson Height...
# 29                      Thorncliffe Park, East Toronto
# ..                                                 ...
# 73   North Toronto West, The Annex, North Midtown, ...
# 74   The Annex, North Midtown, Yorkville, Davisvill...
# 75          Parkdale, Roncesvalles, Runnymede, Swansea
# 76               Canada Post Gateway Processing Centre
# 77   Kingsview Village, Martin Grove Gardens, Richv...
# 78   Agincourt, Clarks Corners, Sullivan, Tam O'Sha...
# 79   Davisville, Moore Park, Summerhill East, Deer ...
# 80   Harbord, University of Toronto, Chinatown, Gra...
# 81                                  Runnymede, Swansea
# 82   Clarks Corners, Sullivan, Tam O'Shanter, Aginc...
# 83   Moore Park, Summerhill East, Deer Park, Forest...
# 84   Chinatown, Grange Park, Kensington Market, CN ...
# 85   Agincourt North, L'Amoreaux East, Milliken, St...
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...
# 88   Humber Bay Shores, Mimico South, New Toronto, ...
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...
# 90          L'Amoreaux West, Steeles West, Upper Rouge
# 91   Rosedale, Stn A PO Boxes 25 The Esplanade, Cab...
# 92   Stn A PO Boxes 25 The Esplanade, Cabbagetown, ...
# 93   Alderwood, Long Branch, Northwest, The Kingswa...
# 94   Northwest, The Kingsway, Montgomery Road, Old ...
# 95                                         Upper Rouge
# 96   Cabbagetown, St. James Town, First Canadian Pl...
# 97   First Canadian Place, Underground city, Church...
# 98   The Kingsway, Montgomery Road, Old Mill North,...
# 99                                Church and Wellesley
# 100   Business reply mail Processing Centre969 Eastern
# 101  Humber Bay, King's Mill Park, Kingsway Park So...
# 102  Kingsway Park South West, Mimico NW, The Queen...
#
# [103 rows x 3 columns]
# (103, 3)
